# %%
# Scenario-Based Teaching: Smart Travel Agent
# 🧑‍🏫 How You Start in Class

# Say this:

# “Imagine you are very busy and you tell your assistant:

# ‘Find me the best flight from Delhi to Mumbai.’

# Now instead of replying with just text, your assistant actually thinks,
# checks data, and gives a final decision.”


# Step 1 — Define Tools

# 👉  “Tools = functions the agent can call”

def search_flights(source, destination):
    return [
        {"airline": "IndiGo", "price": 4500, "time": "6:00 AM"},
        {"airline": "Air India", "price": 5200, "time": "9:00 AM"}
    ]

def check_weather(city):
    return {"city": city, "temperature": 28, "condition": "Clear"}

def calculate_budget(flights):
    cheapest = min(flights, key=lambda x: x["price"])
    return cheapest
    # Step 2 — Agent Brain (Decision + Planning)
def agent_brain(user_query):
    plan = []

    if "flight" in user_query.lower():
        plan.append("search_flights")
        plan.append("check_weather")
        plan.append("choose_best")

    return plan
    # Step 3 — Execution Engine
def execute_plan(plan):
    context = {}

    for step in plan:
        if step == "search_flights":
            print("\n[Action] Searching Flights...")
            context["flights"] = search_flights("Delhi", "Mumbai")
            print(context["flights"])

        elif step == "check_weather":
            print("\n[Action] Checking Weather...")
            context["weather"] = check_weather("Mumbai")
            print(context["weather"])

        elif step == "choose_best":
            print("\n[Action] Choosing Best Option...")
            best = calculate_budget(context["flights"])
            context["best_flight"] = best
            print(best)

    return context
    # Step 4 — Full Agent
def travel_agent(user_query):
    print("User Query:", user_query)

    # Step 1: Plan
    plan = agent_brain(user_query)
    print("\n[Plan]", plan)

    # Step 2: Execute
    result = execute_plan(plan)

    # Step 3: Final Response
    final_output = f"""
Best Flight: {result['best_flight']['airline']} at ₹{result['best_flight']['price']}
Weather: {result['weather']['condition']}, {result['weather']['temperature']}°C
Recommendation: Book the cheapest early flight.
"""
    return final_output
    # Step 5 — Run It
response = travel_agent("Find best flight from Delhi to Mumbai")
print("\nFinal Answer:\n", response)
# Out:
# User Query: Find best flight from Delhi to Mumbai
#
# [Plan] ['search_flights', 'check_weather', 'choose_best']
#
# [Action] Searching Flights...
# [{'airline': 'IndiGo', 'price': 4500, 'time': '6:00 AM'}, {'airline': 'Air India', 'price': 5200, 'time': '9:00 AM'}]
#
# [Action] Checking Weather...
# {'city': 'Mumbai', 'temperature': 28, 'condition': 'Clear'}
#
# [Action] Choosing Best Option...
# {'airline': 'IndiGo', 'price': 4500, 'time': '6:00 AM'}
#
# Final Answer:
#
# Best Flight: IndiGo at ₹4500
# Weather: Clear, 28°C
# Recommendation: Book the cheapest early flight.

# %%
# Scenario-Based Teaching: Smart Shopping Assistant 🛒

# How You Start in Class
# Say this:
# “Imagine you are planning a party and you tell your assistant:
# ‘Find me the best chocolate cake under ₹500.’
# Now instead of replying with just text, your assistant actually thinks,
# checks different bakery options, compares prices, and gives final decision.”

# ----------------------------------------
# Step 1 — Define Tools
# “Tools = functions the agent can call”

def search_cakes():
    return [
        {"shop": "Sweet Treats", "cake": "Chocolate Cake", "price": 450, "rating": 4.5},
        {"shop": "Bake World", "cake": "Chocolate Truffle", "price": 550, "rating": 4.7},
        {"shop": "Cake Hub", "cake": "Chocolate Delight", "price": 400, "rating": 4.2}
    ]

def filter_budget(cakes, budget):
    return [cake for cake in cakes if cake["price"] <= budget]
-
def choose_best(cakes):
    # Best = highest rating within budget
    best = max(cakes, key=lambda x: x["rating"])
    return best


# ----------------------------------------
# Step 2 — Agent Brain (Decision + Planning)

def agent_brain(user_query):
    plan = []

    if "cake" in user_query.lower():
        plan.append("search_cakes")
        plan.append("filter_budget")
        plan.append("choose_best")

    return plan


# ----------------------------------------
# Step 3 — Execution Engine

def execute_plan(plan):
    context = {}

    for step in plan:
        if step == "search_cakes":
            print("\n[Action] Searching Cakes...")
            context["cakes"] = search_cakes()
            print(context["cakes"])

        elif step == "filter_budget":
            print("\n[Action] Filtering by Budget...")
            context["filtered"] = filter_budget(context["cakes"], 500)
            print(context["filtered"])

        elif step == "choose_best":
            print("\n[Action] Choosing Best Option...")
            best = choose_best(context["filtered"])
            context["best_cake"] = best
            print(best)

    return context


# ----------------------------------------
# Step 4 — Full Agent

def shopping_agent(user_query):
    print("User Query:", user_query)

    # Step 1: Plan
    plan = agent_brain(user_query)
    print("\n[Plan]", plan)

    # Step 2: Execute
    result = execute_plan(plan)

    # Step 3: Final Response
    final_output = f"""
Best Cake: {result['best_cake']['cake']}
Shop: {result['best_cake']['shop']}
Price: ₹{result['best_cake']['price']}
Rating: ⭐ {result['best_cake']['rating']}

Recommendation: This is the best-rated cake within your budget. Perfect for your party! 🎉
"""
    return final_output


# ----------------------------------------
# Step 5 — Run It

response = shopping_agent("Find best chocolate cake under ₹500")
print("\nFinal Answer:\n", response)
# Out:
# User Query: Find best chocolate cake under ₹500
#
# [Plan] ['search_cakes', 'filter_budget', 'choose_best']
#
# [Action] Searching Cakes...
# [{'shop': 'Sweet Treats', 'cake': 'Chocolate Cake', 'price': 450, 'rating': 4.5}, {'shop': 'Bake World', 'cake': 'Chocolate Truffle', 'price': 550, 'rating': 4.7}, {'shop': 'Cake Hub', 'cake': 'Chocolate Delight', 'price': 400, 'rating': 4.2}]
#
# [Action] Filtering by Budget...
# [{'shop': 'Sweet Treats', 'cake': 'Chocolate Cake', 'price': 450, 'rating': 4.5}, {'shop': 'Cake Hub', 'cake': 'Chocolate Delight', 'price': 400, 'rating': 4.2}]
#
# [Action] Choosing Best Option...
# {'shop': 'Sweet Treats', 'cake': 'Chocolate Cake', 'price': 450, 'rating': 4.5}
#
# Final Answer:
#
# Best Cake: Chocolate Cake
# Shop: Sweet Treats
# Price: ₹450
# Rating: ⭐ 4.5
#
# Recommendation: This is the best-rated cake within your budget. Perfect for your party! 🎉

# %%
# Fraud Detection ReAct Agent (toy demo)
# Scenario: The Bank’s AI Fraud Agent
# Imagine a bank has deployed an AI-powered fraud detection agent named FraudLLM.
# Its job is to monitor transactions in real time and decide whether they are normal or suspicious.
# Step 1: Thinking (Reasoning)
# Whenever a transaction comes in, FraudLLM first analyzes the details:
# - Example: “Payment to overseas account” → FraudLLM thinks: “Analyzing transaction:
# Payment to overseas account”
# Step 2: Planning (Choosing an Action)
# Based on the thought, FraudLLM decides which tool to use:
# - If the transaction involves overseas transfers or multiple small deposits, it plans to flag as suspicious.
# - Otherwise, it plans to mark as normal.
# Step 3: Acting (Running Tools)
# FraudLLM hands over the decision to FraudTools, which executes the action:
# - flag_suspicious → returns “Suspicious Transaction”
# - mark_normal → returns “Normal Transaction”
# Step 4: Answering (Final Decision)
# Once a clear classification is reached, FraudLLM announces the decision:
# - “Decision: Suspicious Transaction”
# - “Decision: Normal Transaction”


class FraudLLM:
    def think(self, input_text):
        # Simulate reasoning
        return f"Analyzing transaction: {input_text}"

    def plan(self, thought):
        # Decide which tool to use
        if "overseas" in thought or "multiple deposits" in thought:
            return "flag_suspicious"
        else:
            return "mark_normal"

    def answer(self, obs):
        # Final answer
        return f"Decision: {obs}"

class FraudTools:
    def run(self, action):
        # Execute fraud detection actions
        if action == "flag_suspicious":
            return "Suspicious Transaction"
        elif action == "mark_normal":
            return "Normal Transaction"
        else:
            return "Unknown"

def is_final(obs):
    # Stop once we have a clear classification
    return "Transaction" in obs

# Instantiate components
llm = FraudLLM()
tools = FraudTools()

def react_agent(transaction):
    thought = llm.think(transaction)
    action = llm.plan(thought)
    obs = tools.run(action)

    # Loop until final decision
    while not is_final(obs):
        thought = llm.think(obs)
        action = llm.plan(thought)
        obs = tools.run(action)

    return llm.answer(obs)

# 🚀 Try it out
print(react_agent("Payment to overseas account"))
print(react_agent("Salary credited to employee account"))
print(react_agent("Multiple small deposits from different sources"))
# Out:
# Decision: Suspicious Transaction
# Decision: Normal Transaction
# Decision: Normal Transaction

# %%
# Plagiarism Detection ReAct Agent (toy demo)

# Scenario: The University’s AI Plagiarism Agent
# Imagine a university has deployed an AI-powered plagiarism detection agent named PlagiarismLLM.
# Its job is to monitor student essay submissions in real time and decide whether they are original or potentially plagiarized.

# Step 1: Thinking (Reasoning)
# Whenever an essay is submitted, PlagiarismLLM first analyzes the text:
# - Example: “Essay contains large verbatim passages from online sources”
# - PlagiarismLLM thinks: “Analyzing essay: multiple verbatim passages detected.”

# Step 2: Planning (Choosing an Action)
# Based on the thought, PlagiarismLLM decides which tool to use:
# - If the essay has long verbatim matches or suspicious similarity scores, it plans to flag as potential plagiarism.
# - Otherwise, it plans to mark as original work.

# Step 3: Acting (Running Tools)
# PlagiarismLLM hands over the decision to PlagiarismTools, which executes the action:
# - flag_plagiarism → returns “Potential Plagiarism Detected”
# - mark_original → returns “Original Work”

# Step 4: Answering (Final Decision)
# Once a clear classification is reached, PlagiarismLLM announces the decision:
# - “Decision: Potential Plagiarism Detected”
# - “Decision: Original Work”

# Plagiarism Detection ReAct Agent (toy demo)

class PlagiarismLLM:
    def think(self, input_text):
        # Simulate reasoning
        return f"Analyzing essay: {input_text}"

    def plan(self, thought):
        # Decide which tool to use
        if "verbatim" in thought or "similarity" in thought:
            return "flag_plagiarism"
        else:
            return "mark_original"

    def answer(self, obs):
        # Final answer
        return f"Decision: {obs}"

class PlagiarismTools:
    def run(self, action):
        # Execute plagiarism detection actions
        if action == "flag_plagiarism":
            return "Potential Plagiarism Detected"
        elif action == "mark_original":
            return "Original Work"
        else:
            return "Unknown"

def is_final(obs):
    # Stop once we have a clear classification
    return "Work" in obs or "Plagiarism" in obs

# Instantiate components
llm = PlagiarismLLM()
tools = PlagiarismTools()

def react_agent(essay):
    thought = llm.think(essay)
    action = llm.plan(thought)
    obs = tools.run(action)

    # Loop until final decision
    while not is_final(obs):
        thought = llm.think(obs)
        action = llm.plan(thought)
        obs = tools.run(action)

    return llm.answer(obs)

# Try it out
print(react_agent("Essay contains multiple verbatim passages from online sources"))
print(react_agent("Student wrote a completely original essay on climate change"))
print(react_agent("High similarity score detected across multiple paragraphs"))
# Out:
# Decision: Potential Plagiarism Detected
# Decision: Original Work
# Decision: Potential Plagiarism Detected

# %%
API_TOKEN = "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"

# %%
import requests

API_TOKEN = "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"
MODEL_ID = "meta-llama/Meta-Llama-3-8B-Instruct"

API_URL = "https://router.huggingface.co/v1/chat/completions"

headers = {
    "Authorization": f"Bearer {API_TOKEN}",
    "Content-Type": "application/json"
}

def query_llm(prompt: str):
    payload = {
        "model": MODEL_ID,
        "messages": [
            {"role": "user", "content": prompt}
        ],
        "max_tokens": 200
    }

    response = requests.post(API_URL, headers=headers, json=payload)
    data = response.json()

    if "choices" in data:
        return data["choices"][0]["message"]["content"]
    else:
        return str(data)


def flag_suspicious(transaction):
    return "Suspicious Transaction"


def mark_normal(transaction):
    return "Normal Transaction"


def fraud_agent(transaction: str):
    thought = query_llm(f"Analyze this transaction: {transaction}")
    print("LLM Thought:", thought)

    if "overseas" in transaction.lower() or "multiple deposits" in transaction.lower():
        action = flag_suspicious
    else:
        action = mark_normal

    result = action(transaction)

    final_answer = query_llm(f"Decision: {result}")
    return final_answer


print(fraud_agent("Payment to overseas account"))
# Out:
# LLM Thought: To analyze a payment to an overseas account, we need to consider several factors. Here's a general framework to understand the transaction:
#
# **Key Components:**
#
# 1. **Sender**: The person or entity sending the funds, typically from their domestic account.
# 2. **Recipient**: The person or entity receiving the funds, with an overseas account.
# 3. **Payment Method**: The method used to transfer the funds, such as wire transfer, online payment platform, or international bank transfer.
# 4. **Currency**: The currency of the transferred funds.
# 5. **Transaction Value**: The amount of the transaction.
# 6. **Exchange Rate**: The rate at which the sender's currency is converted to the recipient's currency.
# 7. **Fees**: Any charges associated with the transaction, such as transfer fees, exchange rate fees, or intermediary bank fees.
# 8. **Regulatory Compliance**: The transaction's compliance with anti-money laundering (AML) and know-your-customer (KYC) regulations.
#
# **Analysis
# **Suspicious Transaction Decision-Making Process**
#
# When handling a suspicious transaction, it's crucial to follow a structured approach to ensure a thorough evaluation. Here's a step-by-step decision-making process to help you navigate the situation:
#
# ### 1. **Initial Assessment**
#
# *   Review the transaction details, including:
#     *   Date and time
#     *   Transaction amount
#     *   Sender and receiver information
#     *   Transaction type (e.g., deposit, withdrawal, transfer)
# *   Identify any unusual patterns or anomalies in the transaction
#
# ### 2. **Risk Assessment**
#
# *   Evaluate the transaction risk using a risk assessment framework, such as:
#     *   Customer due diligence (CDD)
#     *   Know-Your-Customer (KYC) requirements
#     *   Transaction monitoring and filtering
#     *   High-Risk Transaction (HRT) classification
# *   Determine the risk level (e.g., low, medium, high)
#
# ### 3. **Transaction

# %%
import requests

# 🔐 Token (replace if needed)
API_TOKEN = "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"
MODEL_ID = "meta-llama/Meta-Llama-3-8B-Instruct"

API_URL = "https://router.huggingface.co/v1/chat/completions"

headers = {
    "Authorization": f"Bearer {API_TOKEN}",
    "Content-Type": "application/json"
}

# 🧠 LLM function
def query_llm(prompt: str):
    payload = {
        "model": MODEL_ID,
        "messages": [
            {"role": "user", "content": prompt}
        ],
        "max_tokens": 200
    }

    response = requests.post(API_URL, headers=headers, json=payload)
    data = response.json()

    if "choices" in data:
        return data["choices"][0]["message"]["content"]
    else:
        return str(data)


# 🛠️ Tools
def confirm_slot(request):
    return "Appointment Confirmed"

def suggest_reschedule(request):
    return "Slot Unavailable, Please Reschedule"


# 🤖 MediLLM Agent
def medi_agent(appointment_request: str):

    # Step 1: Thinking
    thought = query_llm(f"Analyze this appointment request: {appointment_request}")
    print("LLM Thought:", thought)

    # Step 2: Planning
    if "10 am" in appointment_request.lower() or "busy" in appointment_request.lower():
        action = suggest_reschedule
    else:
        action = confirm_slot

    # Step 3: Acting
    result = action(appointment_request)

    # Step 4: Final Answer
    final_answer = query_llm(f"Explain this decision: {result}")
    return final_answer


# 🚀 TEST
print(medi_agent("Request for Dr. Sharma at 10 AM tomorrow"))
print(medi_agent("Request for Dr. Sharma at 2 PM tomorrow"))
# Out:
# LLM Thought: Analysis of the appointment request:
#
# 1. **Person involved**: The request is for an appointment with Dr. Sharma, indicating that the request is related to a medical consultation.
#
# 2. **Date and Time**: The appointment is requested for 10 AM tomorrow. This indicates a specific and relatively short notice for the appointment, which may influence the doctor's availability.
#
# 3. **Lack of details**: The request lacks essential details such as:
#    - The patient's name and contact information
#    - The reason for the appointment
#    - Any specific requirements or needs for the appointment
#    - The patient's current health status (if applicable)
#
# 4. **Assumptions**: The sender assumes that Dr. Sharma will be available at 10 AM tomorrow, which might not be the case due to the short notice or unexpected situations.
#
# 5. **Potential issues**:
#    - The doctor's schedule might be fully booked, making it difficult to accommodate the appointment.
#    - The doctor might require additional information
# The decision "Slot Unavailable, Please Reschedule" is typically made by a scheduling system, such as an online booking platform or a calendar application, to inform users that a specific time slot they have requested is no longer available. This message usually indicates that the chosen time slot has been occupied, taken, or otherwise made unavailable.
#
# Reasons for this decision can vary, including:
#
# 1. **Time slot already booked**: Someone else has already booked the same time slot, making it unavailable for the user.
# 2. **Scheduling conflicts**: The system has detected a scheduling conflict with other booked appointments or meetings in the same time slot.
# 3. **Calendar restrictions**: The user may have chosen a time slot that is outside of their allowed working hours or is not available due to other restrictions.
# 4. **System limitations**: The system may not have enough resources or capacity to accommodate the user's requested time slot.
#
# When a user encounters the "Slot Unavailable, Please Reschedule" message, they are
# LLM Thought: Analysis of the Appointment Request:
#
# 1. **Recipient**: The appointment is requested for Dr. Sharma, implying that Dr. Sharma is a medical professional or a healthcare provider.
# 2. **Date and Time**: The appointment is requested for 2 PM tomorrow, indicating a specific date and time.
# 3. **Simple Request**: The request is brief and to the point, lacking any additional details about the purpose of the appointment.
# 4. **Assumes Availability**: The request assumes that Dr. Sharma is available at the requested time, without confirming their schedule.
# 5. **Lack of Context**: There is no information about the reason for the appointment, which may be important for Dr. Sharma to prepare or for the patient to understand the purpose of the visit.
#
# Recommended Improvements:
#
# 1. **Include Reason for Appointment**: Specify the reason for the appointment, such as a follow-up visit, new patient consultation, or a specific concern.
# 2. **Confirm Availability**: Confirm that Dr. Sharma is available at
# However, I don't see any context or information about the appointment in question. Could you provide more details about what appointment is being referred to? For example, is it a job offer, a meeting, or something else?
#
# Once I have more information, I can try to provide a more informed explanation about what "Appointment Confirmed" might mean in that context.
