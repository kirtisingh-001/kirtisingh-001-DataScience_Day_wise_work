# %% [markdown]
# <a href="https://colab.research.google.com/github/kirtisingh-001/kirtisingh-001-DataScience_Day_wise_work/blob/main/Day10_Assessment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Scenario:
# We want to classify whether a restaurant order is “Large” (1) or “Small” (0) based on the number
#  of items ordered.
# - If items ≥ 3 → Large order
# - If items < 3 → Small order

import numpy as np

# Step 1: Data preparation
# X = number of items ordered, y = order size
X = np.array([[1], [2], [3], [5]])   # input: number of items
y = np.array([0, 0, 1, 1])           # output: small=0, large=1

# Step 2: Initialize weights and bias
weights = np.random.rand(1)   # single input -> single weight
bias = np.random.rand(1)
learning_rate = 0.1

# Step 3: Activation Function (Step Function)
def activation(z):
    return 1 if z >= 0 else 0

# Step 4: Training Loop
for epoch in range(10):   # run for 10 iterations
    print(f"Epoch {epoch+1}")

    for i in range(len(X)):
        # Linear combination
        z = np.dot(X[i], weights) + bias
        y_pred = activation(z)

        # Error
        error = y[i] - y_pred

        # Update weights and bias
        weights += learning_rate * error * X[i]
        bias += learning_rate * error

        print(f"Items: {X[i]}, Predicted: {y_pred}, Actual: {y[i]}, Error: {error}")

print("\nFinal Weights:", weights)
print("Final Bias:", bias)

# Step 5: Test the perceptron
test_items = np.array([2, 4])

for items in test_items:
    z = np.dot(items, weights) + bias
    print(f"Items Ordered: {items}, Prediction: {activation(z)}")
# Out:
# Epoch 1
# Items: [1], Predicted: 1, Actual: 0, Error: -1
# Items: [2], Predicted: 1, Actual: 0, Error: -1
# Items: [3], Predicted: 0, Actual: 1, Error: 1
# Items: [5], Predicted: 1, Actual: 1, Error: 0
# Epoch 2
# Items: [1], Predicted: 1, Actual: 0, Error: -1
# Items: [2], Predicted: 1, Actual: 0, Error: -1
# Items: [3], Predicted: 0, Actual: 1, Error: 1
# Items: [5], Predicted: 1, Actual: 1, Error: 0
# Epoch 3
# Items: [1], Predicted: 1, Actual: 0, Error: -1
# Items: [2], Predicted: 1, Actual: 0, Error: -1
# Items: [3], Predicted: 0, Actual: 1, Error: 1
# Items: [5], Predicted: 1, Actual: 1, Error: 0
# Epoch 4
# Items: [1], Predicted: 1, Actual: 0, Error: -1
# Items: [2], Predicted: 1, Actual: 0, Error: -1
# Items: [3], Predicted: 0, Actual: 1, Error: 1
# Items: [5], Predicted: 1, Actual: 1, Error: 0
# Epoch 5
# Items: [1], Predicted: 1, Actual: 0, Error: -1
# Items: [2], Predicted: 1, Actual: 0, Error: -1
# Items: [3], Predicted: 0, Actual: 1, Error: 1
# ...
