# %%
#  Scenario: AI‑Powered Email Assistant
# You’re building an email drafting assistant for a corporate team.
# - When a user starts typing:
# “Artificial Intelligence will…”
# - The assistant uses GPT‑2 to auto‑complete the sentence with a coherent continuation.
# - Example output:
# “Artificial Intelligence will transform the way businesses interact with customers,
# enabling faster decisions and personalized experiences.”
# Install the library
# !pip install -q -U google-generativeai
import google.generativeai as genai
from google.colab import userdata
# Safely fetch the key from Colab Secrets
API_KEY = userdata.get('GOOGLE_API_KEY')
genai.configure(api_key=API_KEY)
print("Gemini is ready!")
# Out:
# /usr/local/lib/python3.12/dist-packages/google/colab/_import_hooks/_hook_injector.py:55: FutureWarning:
#
# All support for the `google.generativeai` package has ended. It will no longer be receiving
# updates or bug fixes. Please switch to the `google.genai` package as soon as possible.
# See README for more details:
#
# https://github.com/google-gemini/deprecated-generative-ai-python/blob/main/README.md
#
#   loader.exec_module(module)
# Gemini is ready!

# %%
model = genai.GenerativeModel('gemini-flash-latest')
# Example: Ask Gemini to help with your project logic
prompt = "Suggest 3 AI features for a farming app that helps with crop disease detection."
response = model.generate_content(prompt)
print(response.text)
# Out:
# To create a truly competitive and high-utility farming app, the AI should move beyond simple image recognition and toward **predictive prevention** and **personalized recovery**.
#
# Here are three innovative AI features for a crop disease detection app:
#
# ### 1. Hyper-Local "Pathogen Forecast" (Predictive Alerts)
# Instead of waiting for the disease to appear, this feature uses predictive analytics to warn farmers *before* an outbreak occurs.
#
# *   **How it works:** The AI integrates real-time weather data (humidity, temperature, wind speed) with historical disease patterns and crowdsourced data from neighboring farms. If the conditions are "perfect" for a specific fungus or pest (e.g., Potato Late Blight after a humid spell), the app sends a push notification.
# *   **The Value:** It shifts the farmer from a **reactive** state (treating a sick plant) to a **proactive** state (applying preventative measures), which is significantly cheaper and saves more of the yield.
#
# ### 2. Multi-Modal "AI Agronomist" Chatbot
# Standard apps often give a generic PDF-style result. This feature uses a Multimodal Large Language Model (like GPT-4o or Gemini) to provide a conversational, interactive diagnostic experience.
#
# *   **How it works:** The farmer takes a photo of the leaf and then *talks* to the app. They might say, "I saw this on the underside of the leaves, and we’ve had heavy rain for three days." The AI combines the visual data (the photo) with the verbal context to provide a nuanced diagnosis.
# *   **Personalization:** The AI can tailor treatment plans based on the farmer's preferences (e.g., "Give me only organic solutions") or local inventory (the AI scans local supplier databases to suggest products actually available in nearby stores).
#
# ### 3. Edge-AI Offline Instant Scan
# Internet connectivity is often unstable in rural fields. This feature uses "Edge AI"—small, compressed neural networks that live directly on the smartphone rather than in the cloud.
#
# *   **How it works:** Using frameworks like TensorFlow Lite, the app performs the complex image analysis locally on the phone's processor. The farmer can point the camera at a crop in a "dead zone" with no bars of signal and receive an instant diagnosis.
# *   **The Value:** Speed and reliability. In farming, time is critical; waiting to get back to a Wi-Fi signal to know if a crop is infected could allow the disease to spread. An instant, offline "point-and-detect" feature ensures the tool is always functional.
#
# ***
#
# ### Summary for your Roadmap:
# | Feature | Technology | Primary Benefit |
# | :--- | :--- | :--- |
# | **Pathogen Forecast** | Predictive Analytics / Big Data | **Prevention:** Stop disease before it starts. |
# | **AI Agronomist** | Multimodal LLM (GenAI) | **Expertise:** Human-like advice tailored to the farmer. |
# | **Edge-AI Scan** | On-device Computer Vision | **Accessibility:** Works in remote fields without internet. |

# %%
from transformers import pipeline
generator=pipeline("text-generation" ,model="gpt2")
print(generator("artificial intelligence will",max_length=30))
# Out:
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# Passing `generation_config` together with generation-related arguments=({'max_length'}) is deprecated and will be removed in future versions. Please pass either a `generation_config` object OR all generation parameters explicitly, but not both.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=30) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [{'generated_text': 'artificial intelligence will also help to shape the future of our everyday lives. Our society will begin to realize that social robots will not only be good for our health and safety, but will also protect us from the dangers of environmental degradation and environmental degradation.\n\nBut while we may be able to create a future in which robots aren\'t bad, they are just as bad. There have been some reports of robots being used for criminal purposes, or in the case of a person with mental illness, "dangerous" and dangerous to life.\n\nWhy is there so much concern about robots?\n\nThe government, in the long run, will not be able to keep up with technological change and will not be able to have a strong enough position of authority to ensure that we do not create robots. The government\'s commitment to the protection of free speech and right to free expression is a necessary condition for the development of a society that respects human rights and that does not rely on or encourage technological change.\n\nWhat are the risks?\n\nSome may speculate that robots will cause harm to human health. That is not true. Robots will not cause harm, but they will harm. When people are able to experience the benefits of robots, they also will experience the dangers.\n\nThere are'}]

# %%
import google.generativeai as genai
from google.colab import userdata

# 1. Fetch your Gemini API Key securely
API_KEY = userdata.get('GOOGLE_API_KEY')
genai.configure(api_key=API_KEY)

# 2. Initialize the model (using Flash for speed)
model = genai.GenerativeModel('gemini-flash-latest')

# %%
def generate_game_story(user_prompt):
    # We add a "System Instruction" to tell Gemini to act like a Game Designer
    system_context = (
        "You are a professional RPG Game Designer. "
        "Complete the following story prompt with a mysterious and engaging fantasy quest idea. "
        "Keep the response concise (2-3 sentences)."
    )
    # Combine the instruction with the user's prompt
    full_prompt = f"{system_context}\n\nPrompt: {user_prompt}"
    # Use the 'model' object initialized in cell 'Wo7XK_sYh1Qx'
    response = model.generate_content(full_prompt)
    return response.text
# --- Scenario ---
user_input = "The hero enters the ancient forest and discovers"
storyline = generate_game_story(user_input)
print("--- Fantasy Quest Generator ---")
print(f"Input: {user_input}...")
print(f"Gemini: {storyline}")
# Out:
# WARNING:tornado.access:404 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 659.26ms
# ---------------------------------------------------------------------------
# NotFound                                  Traceback (most recent call last)
# /tmp/ipykernel_214/2764216336.py in <cell line: 0>()
#      16 # --- Scenario ---
#      17 user_input = "The hero enters the ancient forest and discovers"
# ---> 18 storyline = generate_game_story(user_input)
#      19
#      20 print("--- Fantasy Quest Generator ---")
#
# /tmp/ipykernel_214/2764216336.py in generate_game_story(user_prompt)
#      11
#      12     # Use the 'model' object initialized in cell 'Wo7XK_sYh1Qx'
# ---> 13     response = model.generate_content(full_prompt)
#      14     return response.text
#      15
#
# /usr/local/lib/python3.12/dist-packages/google/generativeai/generative_models.py in generate_content(self, contents, generation_config, safety_settings, stream, tools, tool_config, request_options)
#     329                 return generation_types.GenerateContentResponse.from_iterator(iterator)
#     330             else:
# --> 331                 response = self._client.generate_content(
#     332                     request,
#     333                     **request_options,
#
# /usr/local/lib/python3.12/dist-packages/google/ai/generativelanguage_v1beta/services/generative_service/client.py in generate_content(self, request, model, contents, retry, timeout, metadata)
#     833
#     834         # Send the request.
# --> 835         response = rpc(
#     836             request,
#     837             retry=retry,
#
# /usr/local/lib/python3.12/dist-packages/google/api_core/gapic_v1/method.py in __call__(self, timeout, retry, compression, *args, **kwargs)
#     126             kwargs["compression"] = compression
#     127
# --> 128         return wrapped_func(*args, **kwargs)
#     129
#     130
#
# /usr/local/lib/python3.12/dist-packages/google/api_core/retry/retry_unary.py in retry_wrapped_func(*args, **kwargs)
#     292                 self._initial, self._maximum, multiplier=self._multiplier
#     293             )
# --> 294             return retry_target(
#     295                 target,
#     296                 self._predicate,
#
# /usr/local/lib/python3.12/dist-packages/google/api_core/retry/retry_unary.py in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     154         except Exception as exc:
#     155             # defer to shared logic for handling errors
# --> 156             next_sleep = _retry_error_helper(
#     157                 exc,
#     158                 deadline,
#
# /usr/local/lib/python3.12/dist-packages/google/api_core/retry/retry_base.py in _retry_error_helper(exc, deadline, sleep_iterator, error_list, predicate_fn, on_error_fn, exc_factory_fn, original_timeout)
#     214             original_timeout,
#     215         )
# --> 216         raise final_exc from source_exc
#     217     if on_error_fn is not None:
#     218         on_error_fn(exc)
#
# /usr/local/lib/python3.12/dist-packages/google/api_core/retry/retry_unary.py in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     145     while True:
#     146         try:
# --> 147             result = target()
#     148             if inspect.isawaitable(result):
#     149                 warnings.warn(_ASYNC_RETRY_WARNING)
#
# /usr/local/lib/python3.12/dist-packages/google/api_core/timeout.py in func_with_timeout(*args, **kwargs)
#     128                 kwargs["timeout"] = remaining_timeout
#     129
# --> 130             return func(*args, **kwargs)
#     131
#     132         return func_with_timeout
#
# /usr/local/lib/python3.12/dist-packages/google/api_core/grpc_helpers.py in error_remapped_callable(*args, **kwargs)
#      53     def error_remapped_callable(*args, **kwargs):
#      54         try:
# ---> 55             return callable_(*args, **kwargs)
#      56         except grpc.RpcError as exc:
#      57             raise exceptions.from_grpc_error(exc) from exc
#
# /usr/local/lib/python3.12/dist-packages/google/ai/generativelanguage_v1beta/services/generative_service/transports/rest.py in __call__(self, request, retry, timeout, metadata)
#    1159             # subclass.
#    1160             if response.status_code >= 400:
# -> 1161                 raise core_exceptions.from_http_response(response)
#    1162
#    1163             # Return the response
#
# NotFound: 404 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint: models/gemini-1.5-flash is not found for API version v1beta, or is not supported for generateContent. Call ListModels to see the list of available models and their supported methods.

# %%
import google.generativeai as genai
from google.colab import userdata
# 1. Setup
API_KEY = userdata.get('GOOGLE_API_KEY')
genai.configure(api_key=API_KEY)
# 2. Safety Check: Print exactly what models YOU can use
print("Available models for you:")
for m in genai.list_models():
    if 'generateContent' in m.supported_generation_methods:
        print(f" - {m.name}")
# 3. Use the 'Flash' model (fastest and most reliable for testing)
# Using 'gemini-1.5-flash-latest' is usually the safest alias
model = genai.GenerativeModel('gemini-1.5-flash-latest')
def generate_story():
    try:
        response = model.generate_content("The hero enters the ancient forest and discovers")
        print("\nSuccess! Storyline:")
        print(response.text)
    except Exception as e:
        print(f"\nError encountered: {e}")
generate_story()
# Out:
# Available models for you:
#  - models/gemini-2.5-flash
#  - models/gemini-2.5-pro
#  - models/gemini-2.0-flash
#  - models/gemini-2.0-flash-001
#  - models/gemini-2.0-flash-lite-001
#  - models/gemini-2.0-flash-lite
#  - models/gemini-2.5-flash-preview-tts
#  - models/gemini-2.5-pro-preview-tts
#  - models/gemma-3-1b-it
#  - models/gemma-3-4b-it
#  - models/gemma-3-12b-it
#  - models/gemma-3-27b-it
#  - models/gemma-3n-e4b-it
#  - models/gemma-3n-e2b-it
#  - models/gemini-flash-latest
#  - models/gemini-flash-lite-latest
#  - models/gemini-pro-latest
#  - models/gemini-2.5-flash-lite
#  - models/gemini-2.5-flash-image
#  - models/gemini-2.5-flash-lite-preview-09-2025
#  - models/gemini-3-pro-preview
#  - models/gemini-3-flash-preview
#  - models/gemini-3.1-pro-preview
#  - models/gemini-3.1-pro-preview-customtools
#  - models/gemini-3.1-flash-lite-preview
#  - models/gemini-3-pro-image-preview
#  - models/nano-banana-pro-preview
#  - models/gemini-3.1-flash-image-preview
#  - models/gemini-robotics-er-1.5-preview
#  - models/gemini-2.5-computer-use-preview-10-2025
#  - models/deep-research-pro-preview-12-2025
#
# Error encountered: 404 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-1.5-flash-latest:generateContent?%24alt=json%3Benum-encoding%3Dint: models/gemini-1.5-flash-latest is not found for API version v1beta, or is not supported for generateContent. Call ListModels to see the list of available models and their supported methods.
# WARNING:tornado.access:404 POST /v1beta/models/gemini-1.5-flash-latest:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 786.86ms

# %%
#  Scenario: Game Storyline Generator
# You’re designing a fantasy role‑playing game and need quick ideas for quests and dialogue.
# - The developer types a prompt:
# “The hero enters the ancient forest and discovers…”
# - The GPT‑2 pipeline continues the story:
# “The hero enters the ancient forest and discovers a hidden village where the people whisper of
#  a cursed artifact buried beneath the old ruins.”
import google.generativeai as genai
from google.colab import userdata
# 1. Setup with your key
API_KEY = userdata.get('GOOGLE_API_KEY')
genai.configure(api_key=API_KEY)
# 2. Use the new 3.1 Flash-Lite model
# This model supports "Thinking Levels" to balance speed and quality
model = genai.GenerativeModel('gemini-3.1-flash-lite-preview')
def generate_story(prompt):
    # Gemini 3 models are great at following complex instructions
    response = model.generate_content(
        prompt,
        generation_config={
            "temperature": 1.0, # Great for creative game stories
            "max_output_tokens": 150,
        }
    )
    return response.text
# --- Run the Scenario ---
user_prompt = "The hero enters the ancient forest and discovers"
print(f"Result: {generate_story(user_prompt)}")
# Out:
# Result: The hero enters the ancient forest and discovers that the air itself feels heavy, shimmering with a faint, iridescent haze that tastes like ozone and crushed violets.
#
# As they push through a curtain of hanging moss that feels unnervingly like velvet, the forest floor shifts. The usual decaying leaves and brambles are absent; in their place, the ground is composed of thousands of tightly packed, calcified scrolls, half-buried in the soil like bleached coral.
#
# They take a cautious step forward, and the sound of their boot crunching against a scroll triggers a low, resonant hum that vibrates upward through their soles. Suddenly, the trees—colossal, silver-barked sentinels—begin to stir.

# %%
# Scenario: Research Assistant for Academic Papers
# Imagine you’re building a tool for university researchers who analyze large collections of academic papers.
# - A researcher uploads a sentence:
# “Deep learning models are powerful”
# - Your system uses the BERT tokenizer to break the sentence into smaller units (tokens).
from transformers import AutoTokenizer
tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased")
text = "Deep learning models are powerful"
tokens = tokenizer.tokenize(text)
print(tokens)
# Out:
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# ['deep', 'learning', 'models', 'are', 'powerful']

# %%
# 🏥 Scenario: Healthcare Chatbot for Patient Queries
# A hospital is developing a chatbot to help patients ask questions about their health.
# - A patient types:
# “Deep learning models are powerful” (or in practice, something like “I have chest pain and shortness of breath”).
# - The chatbot uses the BERT tokenizer to break the sentence into tokens:

from transformers import AutoTokenizer
# 1. Initialize the BERT tokenizer (using 'bert-base-uncased' as per your reference)
# In a real medical app, 'emilyalsentzer/Bio_ClinicalBERT' would be even better!
tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased")
# 2. Healthcare Scenario: Patient Query
patient_query = "I have chest pain and shortness of breath"
# 3. Tokenize the input
# This breaks medical terms into manageable units for the AI
tokens = tokenizer.tokenize(patient_query)
# 4. Convert tokens to IDs (the numbers the model actually "reads")
token_ids = tokenizer.convert_tokens_to_ids(tokens)
print(f"Patient Input: {patient_query}")
print(f"Tokens: {tokens}")
print(f"Token IDs: {token_ids}")
# Out:
# Patient Input: I have chest pain and shortness of breath
# Tokens: ['i', 'have', 'chest', 'pain', 'and', 'short', '##ness', 'of', 'breath']
# Token IDs: [1045, 2031, 3108, 3255, 1998, 2460, 2791, 1997, 3052]

# %%
# Scenario: Exploring Creativity in AI Writing
# A university professor is running a workshop on creative writing with AI.
# - The professor gives students the prompt:
# “The future of Artificial Intelligence”
# - The system uses GPT‑2 to generate continuations of the sentence.
# To demonstrate how temperature affects creativity:
# - With temperature = 0.2 (low randomness), the output is more predictable and conservative, e.g.:
# “The future of Artificial Intelligence will bring advancements in healthcare, education, and business.”
from transformers import pipeline
generator = pipeline("text-generation", model="gpt2")
prompt = "The future of Artificial Intelligence"
print(generator(prompt, max_length=40, temperature=0.2))
print(generator(prompt, max_length=40, temperature=0.8))
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Passing `generation_config` together with generation-related arguments=({'max_length', 'temperature'}) is deprecated and will be removed in future versions. Please pass either a `generation_config` object OR all generation parameters explicitly, but not both.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=40) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=40) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [{'generated_text': 'The future of Artificial Intelligence is uncertain.\n\nThe future of Artificial Intelligence is uncertain.\n\nThe future of Artificial Intelligence is uncertain.\n\nThe future of Artificial Intelligence is uncertain.\n\nThe future of Artificial Intelligence is uncertain.\n\nThe future of Artificial Intelligence is uncertain.\n\nThe future of Artificial Intelligence is uncertain.\n\nThe future of Artificial Intelligence is uncertain.\n\nThe future of Artificial Intelligence is uncertain.\n\nThe future of Artificial Intelligence is uncertain.\n\nThe future of Artificial Intelligence is uncertain.\n\nThe future of Artificial Intelligence is uncertain.\n\nThe future of Artificial Intelligence is uncertain.\n\nThe future of Artificial Intelligence is uncertain.\n\nThe future of Artificial Intelligence is uncertain.\n\nThe future of Artificial Intelligence is uncertain.\n\nThe future of Artificial Intelligence is uncertain.\n\nThe future of Artificial Intelligence is uncertain.\n\nThe future of Artificial Intelligence is uncertain.\n\nThe future of Artificial Intelligence is uncertain.\n\nThe future of Artificial Intelligence is uncertain.\n\nThe future of Artificial Intelligence is uncertain.\n\nThe future of Artificial Intelligence is uncertain.\n\nThe future of Artificial Intelligence is uncertain.\n\nThe future of Artificial Intelligence is uncertain.\n\nThe future of Artificial Intelligence is uncertain.\n\nThe'}]
# [{'generated_text': 'The future of Artificial Intelligence will be governed by the future AI market, and this is going to change very quickly."\n\nThe AI market is an area that has been on fire for a number of years. The concept is that the best and brightest people are in charge of creating, developing and executing the AI system that will ultimately lead to the next billion-dollar tech bubble. As the economy is rapidly moving toward AI, and the world of computing comes to be much bigger and more disruptive, those entrepreneurs will have to be able to work with the industry\'s top talent in order to make a great use of the technology that they already have.\n\nI\'d like to thank Dr. Jeff Bezos, Google\'s Chief Global Engagement Officer and co-founder of the Cloud, for this brief discussion.\n\nImage: Shutterstock'}]

# %%
#  Scenario: Scriptwriting Assistant for Film Production
# A film studio is experimenting with AI to help writers brainstorm dialogue and plot ideas.
# - The writer provides the prompt:
# “The future of Artificial Intelligence”
# - The system generates two versions of the continuation:
# - Temperature = 0.2 (low randomness)
# Output is more predictable and formal, e.g.:
# “The future of Artificial Intelligence will improve industries, enhance productivity, and reshape education.”
# → This is useful for serious, factual narration in a documentary script.
# - Temperature = 0.8 (higher randomness)
# Output is more imaginative and varied, e.g.:
# “The future of Artificial Intelligence dances with uncertainty, weaving stories of machines dreaming and societies reborn.”
# → This is perfect for creative dialogue or speculative sci‑fi storytelling

import google.generativeai as genai
from google.colab import userdata
# 1. Setup Gemini
API_KEY = userdata.get('GOOGLE_API_KEY')
genai.configure(api_key=API_KEY)
# Using the newest Flash-Lite model for speed and cost-efficiency
model = genai.GenerativeModel('gemini-3.1-flash-lite-preview')
prompt = "The future of Artificial Intelligence"
def generate_version(temp_value, label):
    # Setting the temperature dynamically
    response = model.generate_content(
        prompt,
        generation_config={
            "temperature": temp_value,
            "max_output_tokens": 50
        }
    )
    print(f"--- {label} (Temp: {temp_value}) ---")
    print(response.text.strip())
    print("-" * 30)
# 2. Version 1: Documentary / Factual Style
generate_version(0.2, "Documentary Narration")
# 3. Version 2: Sci-Fi / Creative Style
generate_version(0.8, "Sci-Fi Dialogue")
# Out:
# --- Documentary Narration (Temp: 0.2) ---
# The future of Artificial Intelligence is not a single destination, but a series of overlapping transitions. We are currently moving from the era of **"Narrow AI"** (tools that perform specific tasks) toward **"General AI"**
# ------------------------------
# --- Sci-Fi Dialogue (Temp: 0.8) ---
# The future of Artificial Intelligence is not a single destination but a trajectory toward the fundamental integration of machine intelligence into every facet of human existence. While we are currently in the era of "Generative AI" (large language models), the
# ------------------------------

# %%
# Scenario: AI‑Powered News Headline Generator
# A digital media company wants to help journalists brainstorm headlines and opening lines for articles.
# - The system asks the journalist to enter a prompt (e.g., “Enter a prompt: The future of Artificial Intelligence”).
# - The GPT‑2 model then generates a continuation of the text, up to 50 tokens.
# - Example output:
# “The future of Artificial Intelligence will reshape industries, redefine creativity, and challenge
#  our understanding of human potential.”

from transformers import pipeline
generator = pipeline("text-generation", model="gpt2")
prompt = input("Enter a prompt: ")
output = generator(prompt, max_length=50)
print(output[0]["generated_text"])
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Enter a prompt: The future of India
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# The future of India's global manufacturing market depends on a future of manufacturing exports in both the form of manufacturing goods and exports of food, fuel, and other goods. As per the Indian government's 'BJP government's 'Aam Aadmi Party's 'Aam Aadmi Party's 'Aam Aadmi Party's platform on 'National Fair Trade' which states, 'Aam Aadmi Party has announced that 'Anchor of India' will be its first Chief Minister of India. It will be the first Chief Minister of India to be of the Bharatiya Janata Party. It is our hope that this will be the first time in history that a Chief Minister of India will be of the Bharatiya Janata Party.' In its announcement, the BJP also said that 'Aam Aadmi Party will lead the country in 'national fair trade.' It also said that 'Aam Aadmi Party has given up its desire to be the first Chief Minister of India in order to achieve its agenda of 'national fair trade.'
#
# The BJP has been one of the leading political parties in the last few decades. It has become a major political party in the country's history. The BJP's leadership has been at the forefront of the political agenda of the country's political parties

# %%
# 🎓 Scenario: Student Brainstorming Tool for Essay Writing
# A college student is struggling to start their essay.
# - The system prompts them:
# “Enter a prompt:”
# - The student types:
# “The impact of technology on education”
# - The GPT‑2 model generates a continuation up to 50 tokens, for example:
# “The impact of technology on education has transformed classrooms, enabling online learning,
# personalized study plans, and global collaboration among students.”

import google.generativeai as genai
from google.colab import userdata
# 1. Setup Gemini with your Secret Key
API_KEY = userdata.get('GOOGLE_API_KEY')
genai.configure(api_key=API_KEY)
# Using 3.1 Flash-Lite for instant brainstorming responses
model = genai.GenerativeModel('gemini-3.1-flash-lite-preview')
# 2. Interactive Input
# The student enters their essay topic here
user_prompt = input("Enter your essay topic or opening sentence: ")
# 3. Generate the Brainstorming Continuation
# We limit tokens to 60 to keep it as a 'starting point' (approx 50-60 words)
response = model.generate_content(
    user_prompt,
    generation_config={
        "max_output_tokens": 60,
        "temperature": 0.7  # Balanced: creative but stays on topic
    }
)
print("\n--- Essay Brainstorming Suggestion ---")
print(response.text.strip())
# Out:
# Enter your essay topic or opening sentence: The impact of technology on education
#
# --- Essay Brainstorming Suggestion ---
# The impact of technology on education has been nothing short of transformative. It has shifted the paradigm from a teacher-centered, textbook-based model to a student-centered, interactive, and globalized experience.
#
# Here is an analysis of how technology has reshaped the educational landscape

# %%
# Scenario: AI Model Evaluation in a Startup
# A startup is building an AI‑powered content assistant to help marketers draft product descriptions.
# - The team wants to compare two models: GPT‑2 (larger, more expressive) and DistilGPT‑2 (smaller, faster, distilled version).
# - They use the same prompt:
# “Artificial Intelligence will transform”
# - The system generates two outputs:
# - GPT‑2 Output
# Longer, more detailed continuation, e.g.:
# “Artificial Intelligence will transform industries by automating processes, enhancing creativity, and
# reshaping how humans interact with technology.”
# → Richer but slower to run.
# - DistilGPT‑2 Output


from transformers import pipeline

gpt2 = pipeline("text-generation", model="gpt2")
distilgpt2 = pipeline("text-generation", model="distilgpt2")

prompt = "Artificial Intelligence will transform"

print("GPT2:", gpt2(prompt, max_length=40))
print("DistilGPT2:", distilgpt2(prompt, max_length=40))
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# config.json:   0%|          | 0.00/762 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/353M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/76 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: distilgpt2
# Key                                        | Status     |  |
# -------------------------------------------+------------+--+-
# transformer.h.{0, 1, 2, 3, 4, 5}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=40) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=40) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# GPT2: [{'generated_text': "Artificial Intelligence will transform our lives in the coming decades.\n\nI have spent a lifetime learning how to learn — and how to build — machine learning. Now I hope to break that comfort barrier and show the world how to learn.\n\nThis is a new era where machine learning is becoming a real, accepted part of the human experience. It is the new digital age of information. By using machine learning to identify patterns of behavior that we don't typically see in other social systems, I hope to show that human beings can learn to create systems that are more self-aware, more self-aware of their own environment, more self-aware of their own experience.\n\nIn this post, I will explore the use of machine learning to understand and improve the human experience of human-computer interactions. I will also share some of the techniques that I use to develop and demonstrate machine learning tools.\n\nIn this post, I will discuss some of the problems and pitfalls of machine learning. I will also explain some of the problems that I believe we cannot solve.\n\nMachine learning is the next big step to learning. It is the next big thing. It has taken years of hard work to achieve, but it has given us a new way to solve problems that we can't solve"}]
# DistilGPT2: [{'generated_text': "Artificial Intelligence will transform the world in many ways. But it will also change many things.\n\n\n\n\nThe technologies that would have enabled us to create AI in the first place are new and exciting, and we should be sure to keep our minds and minds focused on the future.\nBy creating an AI that can understand all of the world’s problems, we are helping to create a new kind of artificial intelligence that can solve the problems and solve them.\nFor example, we can build smart cars that can take the speed of light from cars to cars around the world. And we could create a robot with a very fast voice.\nIt could be a robot that can carry a lot of data, which makes it easier to read, and can even be used as a tool to track your movements.\nAnd we need to go beyond the traditional AI to create smarter cars.\nWe have already introduced a new kind of artificial intelligence that's capable of driving a car.\nSo we are starting to build new, smarter cars.\nWe have already created a new kind of AI that could solve the problems and solve them.\nBut to make things better, we need to create a new kind of artificial intelligence that can solve the problems and solve them.\nAnd we need"}]

# %%
# Scenario: Educational Tool for Classroom Learning
# A high school teacher is introducing students to AI‑powered writing assistants.
# - The teacher wants to show how different models produce different styles of text.
# - They use the same prompt:
# “Artificial Intelligence will transform”
# - The system generates two outputs:
# - GPT‑2 Output
# More elaborate continuation, e.g.:
# “Artificial Intelligence will transform the way societies function, influencing education, healthcare, and the future of human creativity.”
# → Great for showing students how AI can generate rich, detailed ideas.
# - DistilGPT‑2 Output
# Shorter, faster continuation, e.g.:
# “Artificial Intelligence will transform our daily lives.”
# → Useful for demonstrating concise summaries.



import google.generativeai as genai
from google.colab import userdata

# 1. Setup Gemini with your Secret Key
API_KEY = userdata.get('GOOGLE_API_KEY')
genai.configure(api_key=API_KEY)

# 2. Initialize both models
# Pro: Larger, more expressive (like GPT-2)
# Flash-Lite: Smaller, faster, concise (like DistilGPT-2)
model_pro = genai.GenerativeModel('gemini-3.1-pro-preview')
model_lite = genai.GenerativeModel('gemini-3.1-flash-lite-preview')

prompt = "Artificial Intelligence will transform"

def run_comparison(user_prompt):
    # Generating with the 'Pro' model
    output_pro = model_pro.generate_content(user_prompt, generation_config={"max_output_tokens": 50})

    # Generating with the 'Flash-Lite' model
    output_lite = model_lite.generate_content(user_prompt, generation_config={"max_output_tokens": 20})

    print(f"Prompt: {user_prompt}\n")
    print(f"--- Gemini 3.1 Pro (Elaborate) ---")
    print(output_pro.text.strip())
    print("\n--- Gemini 3.1 Flash-Lite (Concise) ---")
    print(output_lite.text.strip())

# Run the experiment
run_comparison(prompt)
# Out:
# WARNING:tornado.access:429 POST /v1beta/models/gemini-3.1-pro-preview:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 912.48ms
# ---------------------------------------------------------------------------
# TooManyRequests                           Traceback (most recent call last)
# /tmp/ipykernel_214/2373515444.py in <cell line: 0>()
#      45
#      46 # Run the experiment
# ---> 47 run_comparison(prompt)
#
# /tmp/ipykernel_214/2373515444.py in run_comparison(user_prompt)
#      33 def run_comparison(user_prompt):
#      34     # Generating with the 'Pro' model
# ---> 35     output_pro = model_pro.generate_content(user_prompt, generation_config={"max_output_tokens": 50})
#      36
#      37     # Generating with the 'Flash-Lite' model
#
# /usr/local/lib/python3.12/dist-packages/google/generativeai/generative_models.py in generate_content(self, contents, generation_config, safety_settings, stream, tools, tool_config, request_options)
#     329                 return generation_types.GenerateContentResponse.from_iterator(iterator)
#     330             else:
# --> 331                 response = self._client.generate_content(
#     332                     request,
#     333                     **request_options,
#
# /usr/local/lib/python3.12/dist-packages/google/ai/generativelanguage_v1beta/services/generative_service/client.py in generate_content(self, request, model, contents, retry, timeout, metadata)
#     833
#     834         # Send the request.
# --> 835         response = rpc(
#     836             request,
#     837             retry=retry,
#
# /usr/local/lib/python3.12/dist-packages/google/api_core/gapic_v1/method.py in __call__(self, timeout, retry, compression, *args, **kwargs)
#     126             kwargs["compression"] = compression
#     127
# --> 128         return wrapped_func(*args, **kwargs)
#     129
#     130
#
# /usr/local/lib/python3.12/dist-packages/google/api_core/retry/retry_unary.py in retry_wrapped_func(*args, **kwargs)
#     292                 self._initial, self._maximum, multiplier=self._multiplier
#     293             )
# --> 294             return retry_target(
#     295                 target,
#     296                 self._predicate,
#
# /usr/local/lib/python3.12/dist-packages/google/api_core/retry/retry_unary.py in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     154         except Exception as exc:
#     155             # defer to shared logic for handling errors
# --> 156             next_sleep = _retry_error_helper(
#     157                 exc,
#     158                 deadline,
#
# /usr/local/lib/python3.12/dist-packages/google/api_core/retry/retry_base.py in _retry_error_helper(exc, deadline, sleep_iterator, error_list, predicate_fn, on_error_fn, exc_factory_fn, original_timeout)
#     214             original_timeout,
#     215         )
# --> 216         raise final_exc from source_exc
#     217     if on_error_fn is not None:
#     218         on_error_fn(exc)
#
# /usr/local/lib/python3.12/dist-packages/google/api_core/retry/retry_unary.py in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     145     while True:
#     146         try:
# --> 147             result = target()
#     148             if inspect.isawaitable(result):
#     149                 warnings.warn(_ASYNC_RETRY_WARNING)
#
# /usr/local/lib/python3.12/dist-packages/google/api_core/timeout.py in func_with_timeout(*args, **kwargs)
#     128                 kwargs["timeout"] = remaining_timeout
#     129
# --> 130             return func(*args, **kwargs)
#     131
#     132         return func_with_timeout
#
# /usr/local/lib/python3.12/dist-packages/google/api_core/grpc_helpers.py in error_remapped_callable(*args, **kwargs)
#      53     def error_remapped_callable(*args, **kwargs):
#      54         try:
# ---> 55             return callable_(*args, **kwargs)
#      56         except grpc.RpcError as exc:
#      57             raise exceptions.from_grpc_error(exc) from exc
#
# /usr/local/lib/python3.12/dist-packages/google/ai/generativelanguage_v1beta/services/generative_service/transports/rest.py in __call__(self, request, retry, timeout, metadata)
#    1159             # subclass.
#    1160             if response.status_code >= 400:
# -> 1161                 raise core_exceptions.from_http_response(response)
#    1162
#    1163             # Return the response
#
# TooManyRequests: 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-3.1-pro-preview:generateContent?%24alt=json%3Benum-encoding%3Dint: You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 0, model: gemini-3.1-pro
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 0, model: gemini-3.1-pro
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_input_token_count, limit: 0, model: gemini-3.1-pro
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_input_token_count, limit: 0, model: gemini-3.1-pro
# Please retry in 23.899959935s.

# %%
import time
from google.api_core import exceptions

def run_comparison(user_prompt):
    try:
        # Generating with the 'Pro' model
        output_pro = model_pro.generate_content(user_prompt, generation_config={"max_output_tokens": 50})

        # Generating with the 'Flash-Lite' model
        output_lite = model_lite.generate_content(user_prompt, generation_config={"max_output_tokens": 20})

        print(f"Prompt: {user_prompt}\n")
        print(f"--- Gemini 3.1 Pro (Elaborate) ---")
        print(output_pro.text.strip())
        print("\n--- Gemini 3.1 Flash-Lite (Concise) ---")
        print(output_lite.text.strip())

    except exceptions.ResourceExhausted as e:
        print("\n[QUOTA ERROR] You hit the rate limit!")
        print("Waiting 30 seconds to let the quota reset...")
        time.sleep(30) # Wait for the window to reset
        run_comparison(user_prompt) # Try one more time automatically

    except Exception as e:
        print(f"\nAn unexpected error occurred: {e}")

# Run the experiment
run_comparison(prompt)
# Out:
# An unexpected error occurred: 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-3.1-pro-preview:generateContent?%24alt=json%3Benum-encoding%3Dint: You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit.
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 0, model: gemini-3.1-pro
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 0, model: gemini-3.1-pro
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_input_token_count, limit: 0, model: gemini-3.1-pro
# * Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_input_token_count, limit: 0, model: gemini-3.1-pro
# Please retry in 52.212411067s.
# WARNING:tornado.access:429 POST /v1beta/models/gemini-3.1-pro-preview:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 2588.96ms

# %%
# Change the model initialization to Flash-Lite
model_pro = genai.GenerativeModel('gemini-3.1-flash-lite-preview') # Substituting Pro with Flash
model_lite = genai.GenerativeModel('gemini-3.1-flash-lite-preview')

# %%
import time
from google.api_core import exceptions
def run_comparison_safe(user_prompt):
    max_retries = 3
    retry_delay = 60  #Seconds to wait after a 429 error
    for attempt in range(max_retries):
        try:
            #Using the Flash-Lite model for better stability
            model = genai.GenerativeModel('gemini-3.1-flash-lite-preview')
            response = model.generate_content(user_prompt)
            print("--- Success! ---")
            print(response.text.strip())
            return #Exit the function once successful
        except exceptions.ResourceExhausted:
            print(f"[Attempt {attempt+1}] Quota exceeded. Retrying in {retry_delay} seconds...")
            time.sleep(retry_delay)
        except Exception as e:
            print(f"An unexpected error occurred: {e}")
            break
run_comparison_safe("Artificial Intelligence will transform")
# Out:
# --- Success! ---
# Artificial Intelligence is widely considered the most transformative technology of the 21st century. Its impact is not limited to a single sector; rather, it is a horizontal technology that is **radically altering the fundamental architecture of human society.**
#
# Here is how AI is transforming key pillars of our world:
#
# ### 1. The Future of Work and Productivity
# AI is moving beyond simple automation (doing repetitive tasks) to **augmentation** (enhancing human cognitive abilities).
# *   **Knowledge Work:** Generative AI is changing how we write, code, design, and analyze data. It is reducing the "drudgery" of professional life but creating a skills gap where proficiency in prompting and AI collaboration is becoming the new baseline.
# *   **The Labor Market:** While there are fears of job displacement, history suggests AI will create entirely new categories of employment, though the transition period may be volatile for those in traditional white-collar roles.
#
# ### 2. Healthcare and Longevity
# This is perhaps the most noble application of AI. We are shifting from reactive "sick care" to proactive, personalized medicine.
# *   **Drug Discovery:** AI can simulate molecular interactions, reducing the time to develop life-saving drugs from years to months.
# *   **Diagnostics:** AI models are now outperforming radiologists in detecting tumors in medical imaging, acting as a "second set of eyes" that never gets tired.
# *   **Genomics:** AI is helping decipher the human genome, paving the way for personalized therapies based on an individual's unique DNA.
#
# ### 3. Education and Knowledge Access
# The "one-size-fits-all" model of schooling is being challenged by the AI-tutor concept.
# *   **Personalized Learning:** AI can adapt to a student’s specific learning pace, identifying exactly where they struggle and adjusting the curriculum in real-time.
# *   **Democratization:** High-quality tutoring, which was previously a luxury for the wealthy, can now be scaled to anyone with an internet connection, potentially leveling the global playing field.
#
# ### 4. Scientific Discovery
# We are entering a "golden age of science" accelerated by AI.
# *   **Complexity Management:** AI can analyze massive datasets—such as climate patterns, protein folding (as seen with AlphaFold), or cosmic signals—that are far beyond the capacity of human cognition.
# *   **New Materials:** Scientists are using AI to discover new materials for batteries, carbon capture, and superconductors, accelerating our transition to a sustainable future.
#
# ### 5. Creativity and Media
# AI is acting as an "amplifier" of human imagination.
# *   **Generative Media:** Tools for image, video, and audio generation are lowering the barrier to entry for creators. What used to require a team of specialists can now be done by a single individual with a vision.
# *   **The "Truth" Challenge:** The flip side is a crisis of trust. Deepfakes and AI-generated misinformation threaten the shared reality necessary for democratic discourse, forcing a transformation in how we verify information.
#
# ### 6. Geopolitics and Security
# AI is becoming the new "nuclear race."
# *   **Power Dynamics:** The countries that lead in compute power, data, and talent will likely define the geopolitical order for the next century.
# *   **Cybersecurity/Warfare:** AI is simultaneously a shield and a sword. It makes cyberattacks more sophisticated and autonomous, forcing a total rethink of national and digital security infrastructure.
#
# ---
#
# ### The Underlying Challenge: The "Human Element"
# As AI transforms these fields, society faces three major existential questions:
#
# 1.  **Alignment:** How do we ensure that AI systems act in accordance with human values, especially as they become more autonomous?
# 2.  **Inequality:** If AI increases the productivity of those who own the tools exponentially more than those who don't, how do we prevent a widening of the wealth gap?
# 3.  **Agency:** If AI makes the decisions—where we drive, what we buy, how we treat an illness—how much autonomy do we surrender, and what does it mean to be "human" in a world of machines?
#
# **In short: Artificial Intelligence is transforming humanity from a species that relies on its own biological intelligence into one that creates and leverages synthetic intelligence to solve problems that were previously unsolvable.** The transformation will not be a sudden event, but a continuous shift that will define the rest of our century.
